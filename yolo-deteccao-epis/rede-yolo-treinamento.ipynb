# %% [markdown]
# ## Treinamento da Rede YOLOV5 com os Dados Pré-Processados

# %%
# baixando a arquitetura de rede e preparando o ambiente de treinamento
# !git clone https://github.com/ultralytics/yolov5  
# %cd yolov5
# %pip install -qr requirements.txt

# %% [markdown]
# ### Importação dos Pacotes Utilitários

# %%
import torch, utils
display = utils.notebook_init() 

from google.colab import drive
drive.mount('/content/drive')
# Out:
# YOLOv5 🚀 v6.1-362-g731a2f8 Python-3.7.13 torch-1.12.0+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# Setup complete ✅ (4 CPUs, 25.5 GB RAM, 37.4/166.8 GB disk)

# %% [markdown]
# ### Baixando o Conjunto de Dados do Servidor

# %%
# !cp /content/drive/MyDrive/Projeto\ -\ Detecção\ de\ EPIs/formatted-dataset.zip /content
# !unzip /content/formatted-dataset.zip

# %% [markdown]
# ### Treinamento da Rede YOLOV5 com os Dados Pré-Processados

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-362-g731a2f8 Python-3.7.13 torch-1.12.0+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...

# %% [markdown]
# ### Verificando o Desempenho da Rede como Novos Vídeos e Imagens

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../video-demo.mp4

# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../image1.png
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../image2.png
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../image3.png
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../image4.png
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../image5.png

# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../video1.png
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../video2.png
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source ../video3.png
