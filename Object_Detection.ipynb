# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-359-g628c05c Python-3.7.13 torch-1.12.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 37.4/78.2 GB disk)

# %%
# !unzip /content/formatted-dataset.zip
# Out:
# Archive:  /content/formatted-dataset.zip
# replace images/train/1.png? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace images/train/10.png? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# Train YOLOv5s
# !python train.py --img 640 --batch 16 --epochs 100 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-359-g628c05c Python-3.7.13 torch-1.12.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %% [markdown]
# ### Verificando resultados

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source ../Homenagem.mp4
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# video 1/1 (8112/13109) /content/Homenagem.mp4: 384x640 Done. (0.008s)
# video 1/1 (8113/13109) /content/Homenagem.mp4: 384x640 Done. (0.009s)
# video 1/1 (8114/13109) /content/Homenagem.mp4: 384x640 Done. (0.009s)
# video 1/1 (8115/13109) /content/Homenagem.mp4: 384x640 1 Luva, Done. (0.009s)
# video 1/1 (8116/13109) /content/Homenagem.mp4: 384x640 1 Luva, Done. (0.010s)
# video 1/1 (8117/13109) /content/Homenagem.mp4: 384x640 1 Luva, Done. (0.008s)
# video 1/1 (8118/13109) /content/Homenagem.mp4: 384x640 1 Luva, Done. (0.009s)
# video 1/1 (8119/13109) /content/Homenagem.mp4: 384x640 Done. (0.009s)
# video 1/1 (8120/13109) /content/Homenagem.mp4: 384x640 Done. (0.009s)
# video 1/1 (8121/13109) /content/Homenagem.mp4: 384x640 Done. (0.008s)
# video 1/1 (8122/13109) /content/Homenagem.mp4: 384x640 Done. (0.009s)
# video 1/1 (8123/13109) /content/Homenagem.mp4: 384x640 Done. (0.009s)
# ...
